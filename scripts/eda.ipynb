# %%
import duckdb
import numpy as np
import pandas as pd

# %%
con = duckdb.connect("/Users/lilou-dangthai/HOMEWARE/db/openflights.duckdb")

con.sql("SHOW TABLES").show()
# Out:
# ┌───────────────┐
# │     name      │
# │    varchar    │
# ├───────────────┤
# │ airlines      │
# │ airports      │
# │ countries     │
# │ dim_airlines  │
# │ dim_airports  │
# │ fct_routes    │
# │ planes        │
# │ routes        │
# │ stg_airlines  │
# │ stg_airports  │
# │ stg_countries │
# │ stg_planes    │
# │ stg_routes    │
# ├───────────────┤
# │    13 rows    │
# └───────────────┘

# %%
df_airports = con.sql("SELECT * FROM stg_airports").df()
df_airlines = con.sql("SELECT * FROM stg_airlines").df()
df_countries = con.sql("SELECT * FROM stg_countries").df()
df_planes = con.sql("SELECT * FROM stg_planes").df()    
df_routes = con.sql("SELECT * FROM stg_routes").df()
df_fct_route = con.sql("SELECT * FROM fct_routes").df()

# %%
df_routes
# Out:
#       Airline  airline_id source_airport  source_airport_id  \
# 0          2B         410            AER               2965
# 1          2B         410            ASF               2966
# 2          2B         410            ASF               2966
# 3          2B         410            CEK               2968
# 4          2B         410            CEK               2968
# ...       ...         ...            ...                ...
# 67658      ZL        4178            WYA               6334
# 67659      ZM       19016            DME               4029
# 67660      ZM       19016            FRU               2912
# 67661      ZM       19016            FRU               2912
# 67662      ZM       19016            OSS               2913
#
#       destination_airport  destination_airport_id codeshare  stops Equipment
# 0                     KZN                    2990      None      0       CR2
# 1                     KZN                    2990      None      0       CR2
# 2                     MRV                    2962      None      0       CR2
# 3                     KZN                    2990      None      0       CR2
# 4                     OVB                    4078      None      0       CR2
# ...                   ...                     ...       ...    ...       ...
# 67658                 ADL                    3341      None      0       SF3
# 67659                 FRU                    2912      None      0       734
# 67660                 DME                    4029      None      0       734
# 67661                 OSS                    2913      None      0       734
# 67662                 FRU                    2912      None      0       734
#
# [67663 rows x 9 columns]

# %%
def convert_datatypes(df, column_types):
    for column, dtype in column_types.items():
        if dtype == 'Int32':
            df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int32')
        elif dtype == 'int32':
            df[column] = pd.to_numeric(df[column], errors='coerce').fillna(-1).astype('int32')
        else:
            df[column] = df[column].astype(dtype)
    return df

# %%
convert_datatypes(df_routes, {'source_airport_id': 'Int32', 'destination_airport_id': 'Int32'})
# Out:
#       Airline  airline_id source_airport  source_airport_id  \
# 0          2B         410            AER               2965
# 1          2B         410            ASF               2966
# 2          2B         410            ASF               2966
# 3          2B         410            CEK               2968
# 4          2B         410            CEK               2968
# ...       ...         ...            ...                ...
# 67658      ZL        4178            WYA               6334
# 67659      ZM       19016            DME               4029
# 67660      ZM       19016            FRU               2912
# 67661      ZM       19016            FRU               2912
# 67662      ZM       19016            OSS               2913
#
#       destination_airport  destination_airport_id codeshare  stops Equipment
# 0                     KZN                    2990      None      0       CR2
# 1                     KZN                    2990      None      0       CR2
# 2                     MRV                    2962      None      0       CR2
# 3                     KZN                    2990      None      0       CR2
# 4                     OVB                    4078      None      0       CR2
# ...                   ...                     ...       ...    ...       ...
# 67658                 ADL                    3341      None      0       SF3
# 67659                 FRU                    2912      None      0       734
# 67660                 DME                    4029      None      0       734
# 67661                 OSS                    2913      None      0       734
# 67662                 FRU                    2912      None      0       734
#
# [67663 rows x 9 columns]

# %%
# convert to pandas nullable Int32 (preserves missing values)
df_routes['airline_id'] = pd.to_numeric(df_routes['airline_id'], errors='coerce').astype('Int32')
df_routes.dtypes

# If you really need numpy int32 (replace missing with -1):
# df_routes['airline_id'] = pd.to_numeric(df_routes['airline_id'], errors='coerce').fillna(-1).astype('int32')
# Out:
# Airline                   object
# airline_id                 Int32
# source_airport            object
# source_airport_id          Int32
# destination_airport       object
# destination_airport_id     Int32
# codeshare                 object
# stops                      int32
# Equipment                 object
# dtype: object

# %%
pd.merge(df_routes, df_airlines, on="airline_id", how="left")
# Out:
#       Airline  airline_id source_airport source_airport_id  \
# 0          2B         410            AER              2965
# 1          2B         410            ASF              2966
# 2          2B         410            ASF              2966
# 3          2B         410            CEK              2968
# 4          2B         410            CEK              2968
# ...       ...         ...            ...               ...
# 67658      ZL        4178            WYA              6334
# 67659      ZM       19016            DME              4029
# 67660      ZM       19016            FRU              2912
# 67661      ZM       19016            FRU              2912
# 67662      ZM       19016            OSS              2913
#
#       destination_airport destination_airport_id codeshare  equipment  \
# 0                     KZN                   2990      None          0
# 1                     KZN                   2990      None          0
# 2                     MRV                   2962      None          0
# 3                     KZN                   2990      None          0
# 4                     OVB                   4078      None          0
# ...                   ...                    ...       ...        ...
# 67658                 ADL                   3341      None          0
# 67659                 FRU                   2912      None          0
# 67660                 DME                   4029      None          0
# 67661                 OSS                   2913      None          0
# 67662                 FRU                   2912      None          0
#
#            airline_name   Alias IATA ICAO    Callsign        Country Active
# 0            Aerocondor      \N   2B  ARD  AEROCONDOR       Portugal      Y
# 1            Aerocondor      \N   2B  ARD  AEROCONDOR       Portugal      Y
# 2            Aerocondor      \N   2B  ARD  AEROCONDOR       Portugal      Y
# 3            Aerocondor      \N   2B  ARD  AEROCONDOR       Portugal      Y
# 4            Aerocondor      \N   2B  ARD  AEROCONDOR       Portugal      Y
# ...                 ...     ...  ...  ...         ...            ...    ...
# 67658  Regional Express      \N   ZL  RXA         REX      Australia      Y
# 67659        Apache Air  Apache   ZM  IWA      APACHE  United States      Y
# 67660        Apache Air  Apache   ZM  IWA      APACHE  United States      Y
# 67661        Apache Air  Apache   ZM  IWA      APACHE  United States      Y
# 67662        Apache Air  Apache   ZM  IWA      APACHE  United States      Y
#
# [67663 rows x 15 columns]

# %%
df_airports
# Out:
#       airport_id                                 airport_name          City  \
# 0              1                               Goroka Airport        Goroka
# 1              2                               Madang Airport        Madang
# 2              3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3              4                               Nadzab Airport        Nadzab
# 4              5  Port Moresby Jacksons International Airport  Port Moresby
# ...          ...                                          ...           ...
# 7693       14106                          Rogachyovo Air Base        Belaya
# 7694       14107                        Ulan-Ude East Airport      Ulan Ude
# 7695       14108                         Krechevitsy Air Base      Novgorod
# 7696       14109                  Desierto de Atacama Airport       Copiapo
# 7697       14110                           Melitopol Air Base     Melitopol
#
#                Country IATA  ICAO   Latitude   Longitude
# 0     Papua New Guinea  GKA  AYGA  -6.081690  145.391998
# 1     Papua New Guinea  MAG  AYMD  -5.207080  145.789001
# 2     Papua New Guinea  HGU  AYMH  -5.826790  144.296005
# 3     Papua New Guinea  LAE  AYNZ  -6.569803  146.725977
# 4     Papua New Guinea  POM  AYPY  -9.443380  147.220001
# ...                ...  ...   ...        ...         ...
# 7693            Russia   \N  ULDA  71.616699   52.478298
# 7694            Russia   \N  XIUW  51.849998  107.737999
# 7695            Russia   \N  ULLK  58.625000   31.385000
# 7696             Chile  CPO  SCAT -27.261200  -70.779198
# 7697           Ukraine   \N  UKDM  46.880001   35.305000
#
# [7698 rows x 8 columns]

# %%
df_merged = df_routes.copy()
df_merged = df_merged.merge(df_airlines, on="airline_id", how="left")
df_merged = df_merged.merge(df_airports, left_on="source_airport_id", right_on="airport_id", how="left", suffixes=('', '_source'))
df_merged = df_merged.merge(df_airports, left_on="destination_airport_id", right_on="airport_id")

# %%
df_merged.columns
# Out:
# Index(['Airline', 'airline_id', 'source_airport', 'source_airport_id',
#        'destination_airport', 'destination_airport_id', 'codeshare',
#        'equipment', 'airline_name', 'Alias', 'IATA_x', 'ICAO_x', 'Callsign',
#        'Country_x', 'Active', 'airport_id_x', 'airport_name_x', 'City_x',
#        'Country_source', 'IATA_source', 'ICAO_source', 'Latitude_x',
#        'Longitude_x', 'airport_id_y', 'airport_name_y', 'City_y', 'Country_y',
#        'IATA_y', 'ICAO_y', 'Latitude_y', 'Longitude_y'],
#       dtype='object')

# %%
df_merged.head()
# Out:
#   Airline  airline_id source_airport  source_airport_id destination_airport  \
# 0      2B         410            AER               2965                 KZN
# 1      2B         410            ASF               2966                 KZN
# 2      2B         410            ASF               2966                 MRV
# 3      2B         410            CEK               2968                 KZN
# 4      2B         410            CEK               2968                 OVB
#
#    destination_airport_id codeshare  equipment airline_name Alias  ...  \
# 0                    2990      None          0   Aerocondor    \N  ...
# 1                    2990      None          0   Aerocondor    \N  ...
# 2                    2962      None          0   Aerocondor    \N  ...
# 3                    2990      None          0   Aerocondor    \N  ...
# 4                    4078      None          0   Aerocondor    \N  ...
#
#   Latitude_x Longitude_x airport_id_y               airport_name_y  \
# 0  43.449902   39.956600         2990  Kazan International Airport
# 1  46.283298   48.006302         2990  Kazan International Airport
# 2  46.283298   48.006302         2962     Mineralnyye Vody Airport
# 3  55.305801   61.503300         2990  Kazan International Airport
# 4  55.305801   61.503300         4078           Tolmachevo Airport
#
#             City_y  Country_y IATA_y ICAO_y Latitude_y Longitude_y
# 0            Kazan     Russia    KZN   UWKD  55.606201   49.278702
# 1            Kazan     Russia    KZN   UWKD  55.606201   49.278702
# 2  Mineralnye Vody     Russia    MRV   URMM  44.225101   43.081902
# 3            Kazan     Russia    KZN   UWKD  55.606201   49.278702
# 4      Novosibirsk     Russia    OVB   UNNT  55.012600   82.650703
#
# [5 rows x 31 columns]

# %%
df_airline_routes = df_merged[
    ['airline_id', 'airline_name',
     'airport_name_x', 'City_x', 'Country_source',
     'airport_name_y', 'City_y', 'Country_y']
].rename(columns={
    'airport_name_x': 'source_airport_name',
    'City_x': 'source_city',
    'Country_source': 'source_country',
    'airport_name_y': 'destination_airport_name',
    'City_y': 'destination_city',
    'Country_y': 'destination_country'
})
df_airline_routes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_airline_routes = df_merged[
#       2     ['airline_id', 'airline_name',
#       3      'airport_name_x', 'City_x', 'Country_source',
#       4      'airport_name_y', 'City_y', 'Country_y']
#       5 ].rename(columns={
#       6     'airport_name_x': 'source_airport_name',
#       7     'City_x': 'source_city',
#       8     'Country_source': 'source_country',
#       9     'airport_name_y': 'destination_airport_name',
#      10     'City_y': 'destination_city',
#      11     'Country_y': 'destination_country'
#      12 })
#      13 df_airline_routes.head()
#
# NameError: name 'df_merged' is not defined

# %%
df_merged[df_merged['airline_id','airline_name', 'Country_source', 'city_x', 'country_y', 'city_y']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/HOMEWARE/openflights_dbt/dbt_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('airline_id', 'airline_name', 'Country_source', 'city_x', 'country_y', 'city_y')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_merged[df_merged['airline_id','airline_name', 'Country_source', 'city_x', 'country_y', 'city_y']]
#
# File ~/HOMEWARE/openflights_dbt/dbt_env/lib/python3.9/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/HOMEWARE/openflights_dbt/dbt_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: ('airline_id', 'airline_name', 'Country_source', 'city_x', 'country_y', 'city_y')

# %%
df_fct_route
# Out:
#        airline_id              airline_name  source_airport_id  \
# 0             410                Aerocondor               2965
# 1             410                Aerocondor               2966
# 2             410                Aerocondor               2966
# 3             410                Aerocondor               2968
# 4             410                Aerocondor               2968
# ...           ...                       ...                ...
# 67235        3498  Midwest Airlines (Egypt)               9756
# 67236        3498  Midwest Airlines (Egypt)               9756
# 67237        3498  Midwest Airlines (Egypt)               6463
# 67238        1266           Avient Aviation               7145
# 67239        1266           Avient Aviation               7147
#
#                  source_airport_name source_country  destination_airport_id  \
# 0        Sochi International Airport         Russia                    2990
# 1                  Astrakhan Airport         Russia                    2990
# 2                  Astrakhan Airport         Russia                    2962
# 3      Chelyabinsk Balandino Airport         Russia                    2990
# 4      Chelyabinsk Balandino Airport         Russia                    4078
# ...                              ...            ...                     ...
# 67235                           None           None                    9757
# 67236                           None           None                    7288
# 67237                           None           None                    7287
# 67238                           None           None                    7147
# 67239                           None           None                    7145
#
#           destination_airport_name destination_country  stops Equipment  \
# 0      Kazan International Airport              Russia      0       CR2
# 1      Kazan International Airport              Russia      0       CR2
# 2         Mineralnyye Vody Airport              Russia      0       CR2
# 3      Kazan International Airport              Russia      0       CR2
# 4               Tolmachevo Airport              Russia      0       CR2
# ...                            ...                 ...    ...       ...
# 67235                         None                None      0       CNC
# 67236                         None                None      0       CNC
# 67237                         None                None      0       CNC
# 67238                         None                None      0       DHP
# 67239                         None                None      0       DHP
#
#        is_direct
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ...          ...
# 67235       True
# 67236       True
# 67237       True
# 67238       True
# 67239       True
#
# [67240 rows x 11 columns]

# %%
df_routes[df_routes['source_airport_id'].isna()]
# Out:
#       Airline  airline_id source_airport  source_airport_id  \
# 38         2B         410            TGK               <NA>
# 54         2G        1654            KCK               <NA>
# 1163       4O       17885            PQM               <NA>
# 2113       5Z       18946            PBZ               <NA>
# 2114       5Z       18946            PBZ               <NA>
# ...       ...         ...            ...                ...
# 66353      Z8         603            ORU               <NA>
# 67468      ZI          21            MLH               <NA>
# 67469      ZI          21            MLH               <NA>
# 67470      ZI          21            MLH               <NA>
# 67471      ZI          21            MLH               <NA>
#
#       destination_airport  destination_airport_id codeshare  stops Equipment
# 38                    DME                    4029      None      0       CR2
# 54                    IKT                    2937      None      0       AN4
# 1163                  MEX                    1824      None      0       SU9
# 2113                  CPT                     797      None      0       BEH
# 2114                  JNB                     813      None      0       BEH
# ...                   ...                     ...       ...    ...       ...
# 66353                 SRZ                    4247      None      0       SWM
# 67468                 ALG                     210      None      0       320
# 67469                 CZL                     221      None      0       320
# 67470                 ORN                     231      None      0       319
# 67471                 QSF                    6492      None      0       320
#
# [220 rows x 9 columns]

# %%
df_fct_route[df_fct_route['source_airport_id'].isna()]
# Out:
#        airline_id              airline_name  source_airport_id  \
# 3867        18946              VivaColombia               <NA>
# 3868        18946              VivaColombia               <NA>
# 3869         2850           IndiGo Airlines               <NA>
# 3870         2850           IndiGo Airlines               <NA>
# 3871         2850           IndiGo Airlines               <NA>
# ...           ...                       ...                ...
# 67647        3498  Midwest Airlines (Egypt)               <NA>
# 67657         692                Air Tahiti               <NA>
# 67658         692                Air Tahiti               <NA>
# 67659        5461                  Wizz Air               <NA>
# 67660        5461                  Wizz Air               <NA>
#
#       source_airport_name source_country  destination_airport_id  \
# 3867                 None           None                     797
# 3868                 None           None                     813
# 3869                 None           None                    2994
# 3870                 None           None                    3042
# 3871                 None           None                    3131
# ...                   ...            ...                     ...
# 67647                None           None                    7029
# 67657                None           None                    <NA>
# 67658                None           None                    <NA>
# 67659                None           None                    <NA>
# 67660                None           None                    <NA>
#
#                              destination_airport_name destination_country  \
# 3867                  Cape Town International Airport        South Africa
# 3868                   OR Tambo International Airport        South Africa
# 3869   Sardar Vallabhbhai Patel International Airport               India
# 3870                             Biju Patnaik Airport               India
# 3871                 Kempegowda International Airport               India
# ...                                               ...                 ...
# 67647                                            None                None
# 67657                                            None                None
# 67658                                            None                None
# 67659                                            None                None
# 67660                                            None                None
#
#        stops Equipment  is_direct
# 3867       0       BEH       True
# 3868       0       BEH       True
# 3869       0       320       True
# 3870       0       320       True
# 3871       0       320       True
# ...      ...       ...        ...
# 67647      0       CNC       True
# 67657      0       ATR       True
# 67658      0       ATR       True
# 67659      0       320       True
# 67660      0       320       True
#
# [220 rows x 11 columns]
